# %%
import pandas as pd # we import pandas library  as pd

# %%
df = pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_public.csv') # df:(Data frame) is a data structure where data can be stored in 2d rows and columns
#here we are reading the csv file using its location and pandas library

# %%
df #we can run directly by saying df which prints the data just like that and in a table format!!
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.shape # This is an attribute used to identify no of rows and columns beause jupyter only prints few rows and columns
# Out:
# (65437, 114)

# %%
df.info() # Notice this is a method which helps us to count rows and columns along with Data Types!!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
df.head(15) #using head method we can get certain first no of rows as per our requirement
df.tail(10) # same as head we use tail to get last entrees of our data
# Out:
#        ResponseId                                         MainBranch  \
# 65427       65428  I am not primarily a developer, but I write co...
# 65428       65429                     I am a developer by profession
# 65429       65430                              I am learning to code
# 65430       65431                              I am learning to code
# 65431       65432                     I am a developer by profession
# 65432       65433                     I am a developer by profession
# 65433       65434                     I am a developer by profession
# 65434       65435                     I am a developer by profession
# 65435       65436                     I am a developer by profession
# 65436       65437                        I code primarily as a hobby
#
#                    Age                                         Employment  \
# 65427  25-34 years old  Not employed, but looking for work;Employed, p...
# ...

# %%
pd.set_option('display.max_columns', 100)# we can use this to set no of columns we can view as per our requirement
pd.set_option('display.max_rows', 85)# same like columns we can use this to set no of rows

# %%
schema_df = pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
schema_df.describe() # This method provides a summary of statistics pertaining to the DataFrame columns, such as count, mean, standard deviation, min,
# Out:
#            qid       qname                                           question  \
# count       87          87                                                 87
# unique      66          87                                                 87
# top     QID337  MainBranch  Which of the following options best describes ...
# freq        10           1                                                  1
#
#        force_resp type selector
# count          66   87       87
# unique          2    5        8
# top         False   MC     MAVR
# freq           56   68       37
