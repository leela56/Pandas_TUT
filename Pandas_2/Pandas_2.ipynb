# %%
people = {         # We initialize this dictionary to understand about data frames
        "first" : ["John", "Joe", "Jane"],
        "last" : ["Den", "Don", "Doe"],
        "email": ["Johnd@gmail.com", "Joed@gmail.com", "JaneD@gmail.com"]
}

# %%
df = pd.DataFrame(people)

# %%
df # 0,1,2, Indexes
# Out:
#   first last            email
# 0  John  Den  Johnd@gmail.com
# 1   Joe  Don   Joed@gmail.com
# 2  Jane  Doe  JaneD@gmail.com

# %%
df['email'] # Column of the DataFrame
# Out:
# 0    Johnd@gmail.com
# 1     Joed@gmail.com
# 2    JaneD@gmail.com
# Name: email, dtype: object

# %%
type(df['email']) # the outout is called as Series which is a list or rows of data which is also said 1D array
# Data Frame as being both rows and columns so Data Frame is container for multiple series!!
# Out:
# pandas.core.series.Series

# %%
df[['last', 'email']] # We pass a list and to see Which returns dataframes and not series because we can see multiple columns
# Out:
#   last            email
# 0  Den  Johnd@gmail.com
# 1  Don   Joed@gmail.com
# 2  Doe  JaneD@gmail.com

# %%
df.columns # Which gives us all columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0] # iloc gives row which is by integer so i in i loc where loc for location and which returned a series
# Out:
# first               John
# last                 Den
# email    Johnd@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1],2]
# Out:
# 0    Johnd@gmail.com
# 1     Joed@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,1],'email'] # We pass [0,1] we are asking for both indexes 0 and 1
# Out:
# 0    Johnd@gmail.com
# 1     Joed@gmail.com
# Name: email, dtype: object

# %%
import pandas as pd

# %%
df =  pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_public.csv')
schema_df = pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head() # if we dont give any values it prints out first 5 rows
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.columns # Returns Columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
df['Age'] # Finding through columns
# Out:
# 0        Under 18 years old
# 1           35-44 years old
# 2           45-54 years old
# 3           18-24 years old
# 4           18-24 years old
#                 ...
# 65432       18-24 years old
# 65433       25-34 years old
# 65434       25-34 years old
# 65435       18-24 years old
# 65436       18-24 years old
# Name: Age, Length: 65437, dtype: object

# %%
df.loc[0,'Age'] # Using loc we find which row does it belong
# Out:
# 'Under 18 years old'

# %%
df.loc[[0,1,2],'Age','check'] # We can pass list and also find it without index in loc
# Out:
# 0    Under 18 years old
# 1       35-44 years old
# 2       45-54 years old
# Name: Age, dtype: object

# %%
df.loc[0:2,'Age':'LearnCode'] # We can also apply list slicing to the get required items
# Out:
#                   Age           Employment RemoteWork   Check  \
# 0  Under 18 years old  Employed, full-time     Remote  Apples
# 1     35-44 years old  Employed, full-time     Remote  Apples
# 2     45-54 years old  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
