# %%
import pandas as pd
people = {         # We initialize this dictionary to understand about data frames
        "first" : ["John", "Joe", "Jane"],
        "last" : ["Den", "Don", "Doe"],
        "email": ["Johnd@gmail.com", "Joed@gmail.com", "JaneD@gmail.com"]
}
df = pd.DataFrame(people)

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'john')

# %%
df[~filt]
# Out:
#   first last            email
# 0  John  Den  Johnd@gmail.com
# 1   Joe  Don   Joed@gmail.com
# 2  Jane  Doe  JaneD@gmail.com

# %%
df =  pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_public.csv')
schema_df = pd.read_csv('C:/Desktop/PANDAS_/stack-overflow-developer-survey-2024/survey_results_schema.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
high_sal = (df['ResponseId'] > 50)

# %%
df.loc[high_sal]
# Out:
#        ResponseId                                         MainBranch  \
# 50             51  I am not primarily a developer, but I write co...
# 51             52                     I am a developer by profession
# 52             53                     I am a developer by profession
# 53             54                     I am a developer by profession
# 54             55                     I am a developer by profession
# ...           ...                                                ...
# 65432       65433                     I am a developer by profession
# 65433       65434                     I am a developer by profession
# 65434       65435                     I am a developer by profession
# 65435       65436                     I am a developer by profession
# 65436       65437                        I code primarily as a hobby
#
#                    Age                              Employment  \
# 50     18-24 years old                      Student, full-time
# ...

# %%
countries = ['India', 'Canada']
filt = df['Country']. isin (countries)
df.loc[filt, 'Country']
# Out:
# 3        Canada
# 16       Canada
# 17        India
# 58        India
# 75        India
#           ...
# 65339     India
# 65383     India
# 65413     India
# 65415     India
# 65428     India
# Name: Country, Length: 6335, dtype: object
